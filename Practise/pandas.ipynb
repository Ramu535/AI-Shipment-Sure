# %% [markdown]
# # Dataset Description
#
# The dataset used for model building contains **10,999 observations** of **12 variables**.
# Below are the details of each variable:
#
# - **ID**:
#   ID Number of Customers.
#
# - **Warehouse block**:
#   The company has a large warehouse divided into blocks **A, B, C, D, E**.
#
# - **Mode of shipment**:
#   The company ships products through multiple modes such as **Ship, Flight, and Road**.
#
# - **Customer care calls**:
#   The number of calls made by customers for shipment enquiry.
#
# - **Customer rating**:
#   Rating given by each customer.
#   - **1** → Lowest (Worst)
#   - **5** → Highest (Best)
#
# - **Cost of the product**:
#   Cost of the product in **US Dollars**.
#
# - **Prior purchases**:
#   The number of prior purchases made by the customer.
#
# - **Product importance**:
#   The company categorizes products based on importance: **low, medium, high**.
#
# - **Gender**:
#   Gender of the customer (**Male, Female**).
#
# - **Discount offered**:
#   Discount offered on the specific product.
#
# - **Weight in gms**:
#   The weight of the product in grams.
#
# - **Reached on time (Target Variable)**:
#   - **1** → Product has **NOT** reached on time
#   - **0** → Product has reached on time

# %%
import pandas as pd

# %%
df=pd.read_csv("Train.csv")
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %%
df.isnull()
# Out:
#           ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0      False            False             False                False
# 1      False            False             False                False
# 2      False            False             False                False
# 3      False            False             False                False
# 4      False            False             False                False
# ...      ...              ...               ...                  ...
# 10994  False            False             False                False
# 10995  False            False             False                False
# 10996  False            False             False                False
# 10997  False            False             False                False
# 10998  False            False             False                False
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                False                False            False
# ...

# %%
df.isnull().any(axis=0)
# Out:
# ID                     False
# Warehouse_block        False
# Mode_of_Shipment       False
# Customer_care_calls    False
# Customer_rating        False
# Cost_of_the_Product    False
# Prior_purchases        False
# Product_importance     False
# Gender                 False
# Discount_offered       False
# Weight_in_gms          False
# Reached.on.Time_Y.N    False
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10994    False
# 10995    False
# 10996    False
# 10997    False
# 10998    False
# Length: 10999, dtype: bool

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.groupby("Warehouse_block")["Customer_rating"].mean()
# Out:
# Warehouse_block
# A    2.957447
# B    2.980360
# C    2.993999
# D    3.017993
# F    2.996727
# Name: Customer_rating, dtype: float64

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
df.head(10)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %%
df.tail(10)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# ...

# %%
df.shape
# Out:
# (10999, 12)

# %%
df.columns.to_list()
# Out:
# ['ID',
#  'Warehouse_block',
#  'Mode_of_Shipment',
#  'Customer_care_calls',
#  'Customer_rating',
#  'Cost_of_the_Product',
#  'Prior_purchases',
#  'Product_importance',
#  'Gender',
#  'Discount_offered',
#  'Weight_in_gms',
#  'Reached.on.Time_Y.N']

# %%
df["Customer_rating"].value_counts()
# Out:
# Customer_rating
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: count, dtype: int64

# %%
df["Date"]="2025-11-08"
df.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# Date                   object
# dtype: object

# %%
df["Date"]=pd.to_datetime(df["Date"])
df.dtypes
# Out:
# ID                              int64
# Warehouse_block                object
# Mode_of_Shipment               object
# Customer_care_calls             int64
# Customer_rating                 int64
# Cost_of_the_Product             int64
# Prior_purchases                 int64
# Product_importance             object
# Gender                         object
# Discount_offered                int64
# Weight_in_gms                   int64
# Reached.on.Time_Y.N             int64
# Date                   datetime64[ns]
# dtype: object

# %%
df["Date"].dt.year
df["Date"].dt.month
df["Date"].dt.day
df["Date"].dt.day_name()
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 10994    Saturday
# 10995    Saturday
# 10996    Saturday
# 10997    Saturday
# 10998    Saturday
# Name: Date, Length: 10999, dtype: object

# %%
pd.to_datetime("today")
# Out:
# Timestamp('2025-08-19 12:27:16.088819')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
#  12  Date                 10999 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(8), object(4)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
# std     3175.28214             1.141490         1.413603            48.063272
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  \
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
df.groupby(["Warehouse_block", "Mode_of_Shipment"])["Customer_rating"].mean()
# Out:
# Warehouse_block  Mode_of_Shipment
# A                Flight              3.070707
#                  Road                2.812925
#                  Ship                2.964573
# B                Flight              2.996622
#                  Road                3.000000
#                  Ship                2.971842
# C                Flight              2.932203
#                  Road                3.068027
#                  Ship                2.991158
# D                Flight              2.818182
#                  Road                3.219178
#                  Ship                3.018474
# F                Flight              3.038851
#                  Road                2.936860
#                  Ship                3.000804
# Name: Customer_rating, dtype: float64

# %%
print(df.shape)
print(df.size) ##rows*columns value

## Count number of shipments per mode.
df.groupby('Mode_of_Shipment').size()
# Out:
# (10999, 13)
# 142987
# Mode_of_Shipment
# Flight    1777
# Road      1760
# Ship      7462
# dtype: int64
